# %% [markdown]
# <a href="https://colab.research.google.com/github/MasWap/Data_science/blob/main/01_IntroPythonPandas_finit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction à Python et Pandas - Exercices

# %% [markdown]
# ## HackerRank
#
# HackerRank est un excellent outil pour apprendre à coder en Python en réalisant des mini-défis. Ci-dessous, en voici quelques-uns sélectionnés pour cette initiation/piqûre de rappel python. Une fois la solution trouvée, effectuez un copier-coller sur ce notebook.
#
#
# *   [Say "Hello, World!" With Python](https://www.hackerrank.com/challenges/py-hello-world/problem)
# *   [Arithmetic Operators](https://www.hackerrank.com/challenges/python-arithmetic-operators/problem)
# *   [Division](https://www.hackerrank.com/challenges/python-division/problem)
# *   [Loops](https://www.hackerrank.com/challenges/python-loops/problem) - (fonction a utiliser : [range()](https://pynative.com/python-range-function/)
# *   [If-Else](https://www.hackerrank.com/challenges/py-if-else/problem) (fonctions a utiliser : [range()](https://pynative.com/python-range-function/) , [%](https://data-flair.training/blogs/python-operator/#targetText=Python%20Arithmetic%20Operator,operators%20for%20basic%20mathematical%20operations.&targetText=Adds%20the%20values%20on%20either%20side%20of%20the%20operator.&targetText=Subtracts%20the%20value%20on%20the%20right%20from%20the%20one%20on%20the%20left.&targetText=Multiplies%20the%20values%20on%20either%20side%20of%20the%20operator.))

# %% [markdown]
# ## Pandas
#
# We're going to manipulate data with `pandas`.
#
# 1. Importer `pandas`
# 2. Appliquer le code ci-dessous :<br>
# Il crée un ensemble de données et le stocke dans la variable cali_houses.

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing as ch
cali_houses = ch()
cali_houses = pd.DataFrame(columns=cali_houses.feature_names, data=cali_houses.data)

# %% [markdown]
# 3. Obtenir un aperçu des cinq premières lignes de l'ensemble de données.
# 4. Calculer la moyenne de toutes les colonnes dans l'ensemble de données.
# 5. Calculer la moyenne de la colonne HouseAge.
# 6. Calculer l'écart type de la colonne Population.
# 7. Décrire les principales statistiques de l'ensemble de données.

# %%
# Partie 3
cali_houses.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Partie 4
print(cali_houses.mean())
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# Partie 5
print(cali_houses['HouseAge'].mean())
# Out:
# 28.639486434108527

# %%
# Partie 6
print(cali_houses['Population'].std())
# Out:
# 1132.462121765341

# %%
# Partie 7
cali_houses.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...
